# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#generate x-values
x = np.linspace(-10, 10, 1000)
#Define the individual components
def g(x):
    return x**2 + 2*x + 5
#Visualize  g(x)
plt.plot(x, g(x))
plt.title("Title Here")
plt.xlabel("Lable Here")
plt.title ("plot of g(x) = sin(x**2 + 2*x + 5) ")
plt.grid(True)
plt.show()
#Define the individual components
def h(x):
    return -0.1 * x


g_values = g(x)
h_values = h(x)

#visualize h(x)
plt.plot (x, h(x))
plt.title('Plot of h(x) = e*(-0.1x)')
plt.grid(True)
plt.show()
